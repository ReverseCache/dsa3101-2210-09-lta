# %%
import pandas as pd
import numpy as np

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):

    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    return c * r

# %%
traffic_image=pd.read_csv('traffic_image.csv')

traffic_incidents=pd.read_csv('traffic_incidents.csv')

traffic_speed=pd.read_csv('traffic_speed.csv')

weather=pd.read_csv('weather.csv')

# %%
traffic_image['key']=0
traffic_incidents['key']=0

# %%
traffic_incidents
# Out:
#                  Type  Latitude   Longitude  \
# 0   Vehicle breakdown  1.340404  103.805190
# 1       Heavy Traffic  1.287262  103.795789
# 2   Vehicle breakdown  1.380154  103.920004
# 3       Heavy Traffic  1.437113  103.768351
# 4            Accident  1.413744  103.823186
# 5       Heavy Traffic  1.325304  103.902392
# 6       Heavy Traffic  1.346660  103.788744
# 7            Accident  1.389219  103.752403
# 8       Heavy Traffic  1.389480  103.759813
# 9       Heavy Traffic  1.418847  103.770948
# 10      Heavy Traffic  1.363671  103.859307
# 11      Heavy Traffic  1.343818  103.641240
#
#                                               Message  key
# 0   (17/10)18:35 Vehicle breakdown on PIE (towards...    0
# 1   (17/10)18:19 Heavy Traffic on AYE (towards MCE...    0
# 2   (17/10)18:05 Vehicle breakdown on TPE (towards...    0
# 3   (17/10)18:03 Heavy Traffic on BKE (towards Woo...    0
# 4   (17/10)17:56 Accident on Sembawang Road (towar...    0
# 5   (17/10)17:53 Heavy Traffic on PIE (towards Cha...    0
# 6   (17/10)17:53 Heavy Traffic on PIE (towards Cha...    0
# 7   (17/10)17:53 Accident on KJE (towards BKE) aft...    0
# 8   (17/10)17:51 Heavy Traffic on KJE (towards BKE...    0
# 9   (17/10)17:36 Heavy Traffic on BKE (towards Woo...    0
# 10  (17/10)17:10 Heavy Traffic on CTE (towards SLE...    0
# 11  (17/10)17:01 Heavy Traffic on AYE (towards Tua...    0

# %%
nearest_incidents=traffic_image.merge(traffic_incidents,'outer','key')
nearest_incidents['distance_from_id']=(np.vectorize(haversine)(nearest_incidents['Latitude_x'],nearest_incidents['Longitude_x'],nearest_incidents['Latitude_y'],nearest_incidents['Longitude_y']))*1000
nearest_incidents.sort_values('distance_from_id').groupby('CameraID').head(1)
# Out:
#      CameraID  Latitude_x  Longitude_x  \
# 866      7794    1.379887   103.920092
# 433      4701    1.287100   103.796330
# 309      2706    1.414142   103.771168
# 255      2702    1.445554   103.768340
# 279      2704    1.429589   103.769311
# ..        ...         ...          ...
# 755      6708    1.345996   103.690160
# 811      6714    1.361742   103.703341
# 362      3705    1.327430   103.973830
# 770      6711    1.337710   103.977827
# 338      3702    1.338310   103.980320
#
#                                              ImageLink  key  \
# 866  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 433  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 309  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 255  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 279  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# ..                                                 ...  ...
# 755  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 811  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 362  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 770  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
# 338  https://dm-traffic-camera-itsc.s3.ap-southeast...    0
#
#                   Type  Latitude_y  Longitude_y  \
# 866  Vehicle breakdown    1.380154   103.920004
# 433      Heavy Traffic    1.287262   103.795789
# 309      Heavy Traffic    1.418847   103.770948
# 255      Heavy Traffic    1.437113   103.768351
# 279      Heavy Traffic    1.437113   103.768351
# ..                 ...         ...          ...
# 755      Heavy Traffic    1.343818   103.641240
# 811           Accident    1.389219   103.752403
# 362  Vehicle breakdown    1.380154   103.920004
# 770  Vehicle breakdown    1.380154   103.920004
# 338  Vehicle breakdown    1.380154   103.920004
#
#                                                Message  distance_from_id
# 866  (17/10)18:05 Vehicle breakdown on TPE (towards...         12.109486
# 433  (17/10)18:19 Heavy Traffic on AYE (towards MCE...         60.322208
# 309  (17/10)17:36 Heavy Traffic on BKE (towards Woo...        126.900220
# 255  (17/10)18:03 Heavy Traffic on BKE (towards Woo...        223.398281
# 279  (17/10)18:03 Heavy Traffic on BKE (towards Woo...        225.914711
# ..                                                 ...               ...
# 755  (17/10)17:01 Heavy Traffic on AYE (towards Tua...       5439.998375
# 811  (17/10)17:53 Accident on KJE (towards BKE) aft...       5503.402194
# 362  (17/10)18:05 Vehicle breakdown on TPE (towards...       6149.733498
# 770  (17/10)18:05 Vehicle breakdown on TPE (towards...       6529.519072
# 338  (17/10)18:05 Vehicle breakdown on TPE (towards...       6800.004356
#
# [87 rows x 10 columns]

# %%
nearest_incidents[nearest_incidents]
# Out:
# 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-10-17/18-35/2704_1834_20221017183527_481011.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEDoaDmFwLXNvdXRoZWFzdC0xIkcwRQIgameLqD%2Bl8p7EJf5fcuEBlH7kb6EgHF587cKUhzrJAMICIQCZqBz4tAb5SrAnw%2BtT8y9I%2FBg4kxnAO6OXiHWPxbm5BirbBAgTEAMaDDM0MDY0NTM4MTMwNCIMsF%2FKODN7sP0tRJpTKrgE%2BSisBfWvV2fSAdAzOKjxzxQBRlaLpRHpAnG3RiGivB3%2B0ZvFS6G8%2B%2By1NQuH5mGwl68LNnkOBhyCIrYvEQW8mAK7KZbqOR2w%2Fs5cwmqMmAAtHvz0GXZjZkq%2F5dg4uctfWM5wx%2FtsjLNLhjoJO75nERK5VT9aO%2FvS3tV8M5irenyAjgC3vycoJ0tfDUshcibMlIWSPzMSV3FUtQefkSrqCqc2wMyQKgpDMqc8cPw58JuVNd41J%2B5NtukA7%2FSOnkrVHhQ8qXq5VlbLWlX%2FVCwZvI8ByTpgUJLxB%2FaInyhNfLQRd8kK%2BkC0r99EfYrdZuJI58%2Bd%2BTDhjUIZjGAwg%2F2DWEMFeFJI3QDePQaavrUB7pFVSuqnqk1wPzYKHzksV9EMGtt5wUmKiHUJNTYR1HfvAO3b6MfMZb6H%2B45exUiMUcq7OCMoAApyFn2IhV42RLuXQW0Q1LiO83142huw%2FB4dpu8VnD11q%2F%2BiEYSHFtKRk2UMT5GXna8N%2FS%2B6HJPXNkg1DIrL9qBW33YWg9ZUpAML%2FJN1%2B2sZnILbgPu%2FqPjfunu4RitEEAtWu4lzj1weO2cb4IvKWQ%2BQD5glDeCdrfAeFRY7VBcc%2BiHrsv7c48LadL0cmfIeCiIG4eanjmWROymWHhyX%2FI3uXfDCFBRCwSRbyClT40XaLGFKHYTuDXj26Jso1Bppjz87ptzcmQyhsdt68nUY0ubzjhuTsmtP0ycNl7b8RCiSJT36V5d9AGZjSQzyyzGQffIXRDCpxrSaBjqpAew4Abk3fLlqbWJLhCa09aFwAWri2l91RudOabTOvrc5qQO9E%2F1iA6KUrUWM40eXaZhH2KWkQYZbmQosXb6bJiPtKckdJq9XHgaWFVGL7wajTV5U359iWa16dlEV1J20CaqFEm1HMuH%2BmUv0zpnblTpWnjtZEhycEw7ORkcHKH9JCEjndK6v5tbHeEhG4mBZ7yyhq39V9c8Lmu0NNUexdtY4M1vKSjDN3Yw%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221017T103533Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4DAD3S2N5%2F20221017%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=52fee68ef8acc6cf995510dc23ec922cc94e69ef093096e8857b6c5efd2597e6'

# %%
df=pd.read_csv('traffic_image_region.csv')
df
